# %%
import secrets
from copy import copy

# %%
def generate_starting_bits(bit_len):
    '''Generates starting bits for generator of degree bit_len
       Zero sequence is unacceptable'''
    starting_bits = secrets.randbits(bit_len)
    while(starting_bits == 0):
        starting_bits =  secrets.randbits(bit_len)
    return starting_bits

# %%
def L1(starting_bits, bit_len):
    '''L1 generator
       Generates sequence of degree 25 and len == bit_len using polynom (x**25 ^ x**3 ^ 1)'''
    if isinstance(starting_bits,int):
        starting_bits =  '{:025b}'.format(starting_bits)
    x = copy(starting_bits)
    #print(starting_bits)
    for i in range(0, bit_len-25):
        x += str(int(x[i]) ^ int(x[i+3]))
    return x

# %%
def L2(starting_bits, bit_len):
    '''L2 generator
       Generates sequence of degree 26 and len == bit_len using polynom (x**26 ^ x**6 ^ x**2 ^ x ^ 1)'''
    if isinstance(starting_bits,int):
        starting_bits =  '{:026b}'.format(starting_bits)
    y = copy(starting_bits)
    #print(starting_bits)
    for i in range(0, bit_len-26):
        y += str(int(y[i]) ^ int(y[i+1]) ^ int(y[i+2]) ^ int(y[i+6]))
    return y

# %%
def L3(starting_bits, bit_len):
    '''L3 generator
       Generates sequence of degree 27 and len == bit_len using polynom (x**27 ^ x**5 ^ x**2 ^ x ^ 1)'''
    if isinstance(starting_bits,int):
        starting_bits =  '{:027b}'.format(starting_bits)
    s = copy(starting_bits)
    #print(starting_bits)
    for i in range(0, bit_len-27):
        s += str(int(s[i]) ^ int(s[i+1]) ^ int(s[i+2]) ^ int(s[i+5]))
    return s

# %%
def Geffe(bit_len, L1_starting, L2_starting, L3_starting):
    '''Geffe generator. 
       First generates L1, L2 and L3 sequences of len == bit_len using given starting bits
       Then uses function z = sx ^ (1^ s)*y to generate output'''
    x = L1(L1_starting, bit_len)
    y = L2(L2_starting, bit_len)
    s = L3(L3_starting, bit_len)
    z = ''
    for i in range(bit_len):
        z+= str((int(s[i]) * int(x[i])) ^ (1 ^ int(s[i])) *int(y[i]) )
    return z

# %% [markdown]
# Generated sequence to break for variant 13

# %%
zi = '...'

# %% [markdown]
# Statistical constants for checking hypothesis for key generations for L1 and L2.
# L1 :
#     N1 - amount of symbols of zi needed to count statistic R
#     C1 - constant. If R < C1, key is quite possible
# L2 :
#     N2 - amount of symbols of zi needed to count statistic R
#     C2 - constant. If R < C2, key is quite possible

# %%
C1 = 70.2525951358299
N1 = 222
C2 = 73
N2 = 229

# %% [markdown]
# Possible keys for L1 taken from file Lab4_var13

# %%
res_L1 = ['0000101001100111000111011', '0000110100011010011110100', '0000110100011110011010100', '0000110100011110011110100', '0000111000011010011010000', '0000111000011010011010100', '0000111000011010111010100', '0000111100011010111010100', '0000111100011110011010100', '0001010000011010101010100', '0001010000011010111000100', '0001010000011010111010100', '0001010000111010011010100', '0001010000111110011110100', '0001010000111110111010100', '0001010100011000111010100', '0001010100011010011010100', '0001010100011010101010100', '0001010100011010111010100', '0001010100011010111100100', '0001010100011010111110100', '0001010100011110111010100', '0001010100111110
010001100101100110', '0111100110001000001100110', '0111100110001000101000100', '0111100110001000101000110', '0111100110001100001100110', '0111100110001100101000110', '0111100110001100101100110', '0111101010001000001100110', '1000110000011010011010100', '1000110100011010011110100', '1000110100011010111010100', '1000111000011010111010100', '1000111100011010111010100', '1001010000111110011110000', '1001010100011010011110000', '1001010100011010111110000', '1001010100011010111110100', '1001010100011110111110100', '1001010100111110011110000', '1001010100111110111110000', '1001110000011010011010000', '1001110000011010011010100', '1001110000011010011110000', '1001110000011010111010100', '1001110000011010111110000', '1001110000011010111110100', '1001110000011110011110000', '1001110000011110111110100', '1001110000111110011010000', '1001110000111110011010100', '1001110000111110011110000', '1001110000111110111110100', '1001110100011010011110000', '1001110100011010011110100', '1001110100011010111010000', '1001110100011010111010100', '1001110100011010111110000', '1001110100011010111110100', '1001110100011110011010000', '1001110100011110011010100', '1001110100011110011110000', '1001110100011110011110100', '1001110100011110111110100', '1001110100111010011110000', '1001110100111110011110000', '1001110100111110111010000', '1001111000011010011010000', '1001111000011010011010100', '1011000010001100101100110', '1011000010101100101000010', '1011000110001000001100010', '1011000110001100101100110', '1011000110001100101110100', '1011000110101100101000010', '1011000110101100101100010', '1011001110101100101000010', '1011100110001100101000010', '1011100110001100101100110', '1100001101000011100011111', '1100010100011010111010100', '1100011100011010111010100', '1100011100011010111110100', '1100011100111110111110100', '1101010000011010011110000', '1101010000011110111110100', '1101010000111010111110000', '1101010000111110011110000', '1101010000111110111010000', '1101010100001110111110110', '1101010100011010011010000', '1101010100011010011110000', '1101010100011010111010100', '1101010100011010111110000', '1101010100011010111110100', '1101010100011110011110000', '1101010100011110111110100', '1101010100011110111110110', '1101010100111010111110000', '1101010100111110011110000', '1101010100111110111010000', '1101010100111110111110000', '1101010100111110111110100', '1101010101111110111110000', '1101011101011010111110100', '1101011101111110111110100', '1101110100011010011110000', '1101110100011110111110100', '1101110100111110011110000', '1111000110001100101100110', '1111000110001100101110110', '1111100010001000001100010', '1111100010001100101100110', '1111100110001100001100010', '1111100110001100101100110']

# %% [markdown]
# Statistics R for each of the keys from L1

# %%
def analyze_stats(lst, N1):
    '''Returns dictionary with statistics R for each key from L1.'''
    stat = {}
    z = zi[:N1]
    for l in lst:
        x = L1(l, N1)
        R = sum(int(x[d]) ^ int(z[d]) for d in range(N1))
        stat[l] = R
    return stat

# %%
stats_L1 = analyze_stats(res_L1, N1)
print(stats_L1)
# Out:
# {'0000101001100111000111011': 70, '0000110100011010011110100': 69, '0000110100011110011010100': 69, '0000110100011110011110100': 68, '0000111000011010011010000': 69, '0000111000011010011010100': 66, '0000111000011010111010100': 67, '0000111100011010111010100': 68, '0000111100011110011010100': 70, '0001010000011010101010100': 69, '0001010000011010111000100': 67, '0001010000011010111010100': 62, '0001010000111010011010100': 70, '0001010000111110011110100': 70, '0001010000111110111010100': 70, '0001010100011000111010100': 70, '0001010100011010011010100': 68, '0001010100011010101010100': 68, '0001010100011010111010100': 63
# %% [markdown]
# Sorting dictionary with statistics from smaller to larger

# %%
sorted_L1 = sorted(stats_L1.items(), key=lambda x: x[1])
sorted_L1
# Out:
# [('0001110100011010111010100', 56),
#  ('0101010100011010111010100', 56),
#  ('0001110000011010111010100', 59),
#  ('0101010100011010111110100', 59),
#  ('0001110000011010011010100', 60),
#  ('0101010000011010111010100', 61),
#  ('1101010100111110111110000', 61),
#  ('0001010000011010111010100', 62),
#  ('0001010100011010111010100', 63),
#  ('0001111000011010011010100', 63),
#  ('0101010100111110111110100', 63),
#  ('0101110100011010111010100', 63),
#  ('1001110000111110011110000', 63),
#  ('1101010100011010111110000', 63),
#  ('0001010100011010111110100', 64),
#  ('0001110100011010011110100', 64),
#  ('0001110100011110011010100', 64),
#  ('0101010100011010101010110', 64),
#  ('0101010100111110111110000', 64),
#  ('0101110000011010111010100', 64),
#  ('0111100110001100001100110', 64),
#  ('1001110100011010011110000', 64),
#  ('1101010100011010111110100', 64),
#  ('0001110100011010101010100', 65),
#  ('0001110100011010111110100', 65),
#  ('0001110100011110011110100', 65),
#  ('0011000110001000101000110', 65),
#  ('0101010100011010111010110', 65),
#  ('1001110000011010011010100', 65),
#  ('1001110000011010011110000', 65),
#  ('1001110100011110011010100', 65),
#  ('1001110100011110011110000', 65),
#  ('1001110100011110111110100', 65),
#  ('1011000110101100101000010', 65),
#  ('1100001101000011100011111', 65),
#  ('1101010000111110011110000', 65),
#  ('1101010100011110111110100', 65),
#  ('0000111000011010011010100', 66),
#  ('0001110000011010101010100', 66),
#  ('0001110000011010111000100', 66),
#  ('0001110000011010111010110', 66),
#  ('0001110000011010111110100', 66),
#  ('0001110000111110011010100', 66),
#  ('0001110100011110111110100', 66),
#  ('0001110100111110111010100', 66),
#  ('0001111000010010011010100', 66),
#  ('0101010100011110111110100', 66),
#  ('0101010100111110011110100', 66),
#  ('0101010100111110111010100', 66),
#  ('0101011100010010111010100', 66),
#  ('0111000110001000101000110', 66),
#  ('0111100010001000001100110', 66),
#  ('1000110000011010011010100', 66),
#  ('1001110000011010011010000', 66),
#  ('1001110100011010111110100', 66),
#  ('1001110100111110011110000', 66),
#  ('1011000110001100101100110', 66),
#  ('1100011100011010111110100', 66),
#  ('1101010100111110011110000', 66),
#  ('1101010100111110111110100', 66),
#  ('0000111000011010111010100', 67),
#  ('0001010000011010111000100', 67),
#  ('0001110000011010011010000', 67),
#  ('0001110000011010011110100', 67),
#  ('0001110000111110011110100', 67),
#  ('0001110100011010011010100', 67),
#  ('0001111100011010011110100', 67),
#  ('0011100010001000101000110', 67),
#  ('0100011101111110111110000', 67),
#  ('0101010000111010111110100', 67),
#  ('0101010000111110011110100', 67),
#  ('0101010000111110111010100', 67),
#  ('0101010100001010101010110', 67),
#  ('0101010100011010011010100', 67),
#  ('0101010100011010101010100', 67),
#  ('0101010100111010111010100', 67),
#  ('0101011100011010111010100', 67),
#  ('0101110100011110111110100', 67),
#  ('0111000110001000101010110', 67),
#  ('0111100110001000001100110', 69),
#  ('0111101010001000001100110', 69),
#  ('1000111100011010111010100', 69),
#  ('1001010100011010011110000', 69),
#  ('1001010100111110011110000', 69),
#  ('1001110000011010111110100', 69),
#  ('1001110000111110011010100', 69),
#  ('1001110100011010111010100', 69),
#  ('1001110100111010011110000', 69),
#  ('1001111000011010011010000', 69),
#  ('1011000010001100101100110', 69),
#  ('1011000110001000001100010', 69),
#  ('1011100110001100101000010', 69),
#  ('1011100110001100101100110', 69),
#  ('1100011100011010111010100', 69),
#  ('1101010100001110111110110', 69),
#  ('1101010100011010011010000', 69),
#  ('1101010100011010111010100', 69),
#  ('1101110100011010011110000', 69),
#  ('1101110100111110011110000', 69),
#  ('1111100010001100101100110', 69),
#  ('0000101001100111000111011', 70),
#  ('0000111100011110011010100', 70),
#  ('0001010000111010011010100', 70),
#  ('0001010000111110011110100', 70),
#  ('0001010000111110111010100', 70),
#  ('0001010100011000111010100', 70),
#  ('0001010100011110111010100', 70),
#  ('0001010100111110111110100', 70),
#  ('0001110000001010111010100', 70),
#  ('0001110000111110111110100', 70),
#  ('0001110100001010111010110', 70),
#  ('0001110100011010011010000', 70),
#  ('0001110100011110011110000', 70),
#  ('0001111000011010010010100', 70),
#  ('0001111000011010011110100', 70),
#  ('0001111101011010111010100', 70),
#  ('0011000010001000101010100', 70),
#  ('0011000010001100101100110', 70),
#  ('0011000010101000101000010', 70),
#  ('0011000110001100101000110', 70),
#  ('0011000110001100101010100', 70),
#  ('0011000110101100101100110', 70),
#  ('0011100110001100101100110', 70),
#  ('0100001101000111100111111', 70),
#  ('0100010100011010111110100', 70),
#  ('0101000100001010101010111', 70),
#  ('0101010000011010111110100', 70),
#  ('0101010000111010111110000', 70),
#  ('0101010100001000101010110', 70),
#  ('0101010100001110111110110', 70),
#  ('0101010100011010011110100', 70),
#  ('0101010100011010111000110', 70),
#  ('0101010100111010011010100', 70),
#  ('0101011100000010111011111', 70),
#  ('0101011100011010111110100', 70),
#  ('0101011101111110111110000', 70),
#  ('0101110100011010111110100', 70),
#  ('0111000110001010101010110', 70),
#  ('0111000110101100001100110', 70),
#  ('0111100010001100101100110', 70),
#  ('0111100110001000101000100', 70),
#  ('0111100110001100101000110', 70),
#  ('1000110100011010011110100', 70),
#  ('1000110100011010111010100', 70),
#  ('1000111000011010111010100', 70),
#  ('1001010000111110011110000', 70),
#  ('1001010100011010111110000', 70),
#  ('1001010100111110111110000', 70),
#  ('1001110000011010111010100', 70),
#  ('1001110000011010111110000', 70),
#  ('1001110000011110011110000', 70),
#  ('1001110000111110011010000', 70),
#  ('1001110100011010111010000', 70),
#  ('1001110100011110011110100', 70),
#  ('1001110100111110111010000', 70),
#  ('1001111000011010011010100', 70),
#  ('1011000010101100101000010', 70),
#  ('1011000110001100101110100', 70),
#  ('1011000110101100101100010', 70),
#  ('1011001110101100101000010', 70),
#  ('1100011100111110111110100', 70),
#  ('1101010000011110111110100', 70),
#  ('1101010100111010111110000', 70),
#  ('1101010101111110111110000', 70),
#  ('1101011101011010111110100', 70),
#  ('1101011101111110111110100', 70),
#  ('1111000110001100101110110', 70),
#  ('1111100010001000001100010', 70),
#  ('1111100110001100001100010', 70)]

# %%
sorted_L1[0]
# Out:
# ('0001110100011010111010100', 56)

# %% [markdown]
# Filtering keys. Getting rid of keys where zi != (yi or xi) and creating mask with some known values ('0' or '1')
# and some unknown values('?') for further analysis

# %%
S_var = []
for j in range(len(sorted_L1)):
    x = sorted_L1[j][0]
    y = res_L2[0]
    s = '?' * 25
    res = ''
    for i in range(25):
        if (zi[i] != y[i]):
            if zi[i] == x[i]:
                s = s[:i] + '1' + s[i+1:]
                res += x[i]
            else: 
                print('wrong key')
                break
        else:
            if (zi[i] != x[i]):
                s = s[:i] + '0' + s[i+1:]
                res += y[i]
            else:
                res+='?'
    else:
        S_var.append([x, s])
        print('S {}: {}'.format(j, s))
        print('Z {}: {}'.format(j, res))
S_var
# Out:
# S 0: ???10?1????0??1100?1??111
# Z 0: ???10?0????0??1000?0??100
# S 1: ?0?1??1????0??1100?1??111
# Z 1: ?0?1??0????0??1000?0??100
# S 2: ???10?10???0??1100?1??111
# Z 2: ???10?01???0??1000?0??100
# wrong key
# S 4: ???10?10???0??11?0?1??111
# Z 4: ???10?01???0??10?0?0??100
# S 5: ?0?1??10???0??1100?1??111
# Z 5: ?0?1??01???0??1000?0??100
# wrong key
# S 7: ???1??10???0??1100?1??111
# Z 7: ???1??01???0??1000?0??100
# S 8: ???1??1????0??1100?1??111
# Z 8: ???1??0????0??1000?0??100
# wrong key
# wrong key
# S 11: ?0?10?1????0??1100?1??111
# Z 11: ?0?10?0????0??1000?0??100
# wrong key
# wrong key
# wrong key
# wrong key
# S 16: ???10?1????0?011?0?1??111
# Z 16: ???10?0????0?010?0?0??100
# wrong key
# wrong key
# S 19: ?0?10?10???0??1100?1??111
# Z 19: ?0?10?01???0??1000?0??100
# wrong key
# wrong key
# wrong key
# S 23: ???10?1????0??110??1??111
# Z 23: ???10?0????0??100??0??100
# wrong key
# wrong key
# wrong key
# wrong key
# S 28: 0??10?10???0??11?0?1??111
# Z 28: 0??10?01???0??10?0?0??100
# wrong key
# S 30: 0??10?1????0?011?0?1??111
# Z 30: 0??10?0????0?010?0?0??100
# wrong key
# wrong key
# wrong key
# wrong key
# wrong key
# wrong key
# wrong key
# S 38: ???10?10???0??110??1??111
# Z 38: ???10?01???0??100??0??100
# S 39: ???10?10???0??1100?10?111
# Z 39: ???10?01???0??1000?01?100
# wrong key
# wrong key
# S 42: ???10?10??00?011?0?1??111
# Z 42: ???10?01??00?010?0?0??100
# wrong key
# S 44: ???10?1???00?01100?1??111
# Z 44: ???10?0???00?01000?0??100
# wrong key
# wrong key
# wrong key
# S 48: ?0?1??1???00?01100?1??111
# Z 48: ?0?1??0???00?01000?0??100
# wrong key
# wrong key
# wrong key
# wrong key
# wrong key
# wrong key
# wrong key
# wrong key
# wrong key
# wrong key
# wrong key
# wrong key
# S 61: ???1??10???0??1100?10?111
# Z 61: ???1??01???0??1000?01?100
# wrong key
# wrong key
# wrong key
# S 65: ???10?1????0??11?0?1??111
# Z 65: ???10?0????0??10?0?0??100
# wrong key
# wrong key
# wrong key
# wrong key
# wrong key
# wrong key
# wrong key
# wrong key
# wrong key
# wrong key
# wrong key
# wrong key
# wrong key
# wrong key
# wrong key
# wrong key
# wrong key
# wrong key
# wrong key
# wrong key
# wrong key
# wrong key
# wrong key
# wrong key
# wrong key
# [['0001110100011010111010100', '???10?1????0??1100?1??111'],
#  ['0101010100011010111010100', '?0?1??1????0??1100?1??111'],
#  ['0001110000011010111010100', '???10?10???0??1100?1??111'],
#  ['0001110000011010011010100', '???10?10???0??11?0?1??111'],
#  ['0101010000011010111010100', '?0?1??10???0??1100?1??111'],
#  ['0001010000011010111010100', '???1??10???0??1100?1??111'],
#  ['0001010100011010111010100', '???1??1????0??1100?1??111'],
#  ['0101110100011010111010100', '?0?10?1????0??1100?1??111'],
#  ['0001110100011110011010100', '???10?1????0?011?0?1??111'],
#  ['0101110000011010111010100', '?0?10?10???0??1100?1??111'],
#  ['0001110100011010101010100', '???10?1????0??110??1??111'],
#  ['1001110000011010011010100', '0??10?10???0??11?0?1??111'],
#  ['1001110100011110011010100', '0??10?1????0?011?0?1??111'],
#  ['0001110000011010101010100', '???10?10???0??110??1??111'],
#  ['0001110000011010111000100', '???10?10???0??1100?10?111'],
#  ['0001110000111110011010100', '???10?10??00?011?0?1??111'],
#  ['0001110100111110111010100', '???10?1???00?01100?1??111'],
#  ['0101010100111110111010100', '?0?1??1???00?01100?1??111'],
#  ['0001010000011010111000100', '???1??10???0??1100?10?111'],
#  ['0001110100011010011010100', '???10?1????0??11?0?1??111'],
#  ['0101010000111110111010100', '?0?1??10??00?01100?1??111'],
#  ['0101010100011010011010100', '?0?1??1????0??11?0?1??111'],
#  ['0101010100011010101010100', '?0?1??1????0??110??1??111'],
#  ['0101010100111010111010100', '?0?1??1???00??1100?1??111'],
#  ['0001010100011010011010100', '???1??1????0??11?0?1??111'],
#  ['0001010100011010101010100', '???1??1????0??110??1??111'],
#  ['0001010100111110011010100', '???1??1???00?011?0?1??111'],
#  ['0001110000011110111010100', '???10?10???0?01100?1??111'],
#  ['0001110000111010111010100', '???10?10??00??1100?1??111'],
#  ['0001110100001010101010100', '???10?1???????110??1??111'],
#  ['0001110100111010011010100', '???10?1???00??11?0?1??111'],
#  ['0001110101010010111010100', '???10?1??0?00?1100?1??111'],
#  ['0101010000011110111010100', '?0?1??10???0?01100?1??111'],
#  ['0101010000111010111010100', '?0?1??10??00??1100?1??111'],
#  ['0101010101010010111010100', '?0?1??1??0?00?1100?1??111'],
#  ['0001010000011010101010100', '???1??10???0??110??1??111'],
#  ['0001110000011110011010100', '???10?10???0?011?0?1??111'],
#  ['0001110000111110111010100', '???10?10??00?01100?1??111'],
#  ['0001110001010010111010100', '???10?10?0?00?1100?1??111'],
#  ['0001110010011010111000100', '???10?100??0??1100?10?111'],
#  ['0001110100011110111010100', '???10?1????0?01100?1??111'],
#  ['0001110100111010111010100', '???10?1???00??1100?1??111'],
#  ['0101010100001010111010100', '?0?1??1???????1100?1??111'],
#  ['0101010100111110011010100', '?0?1??1???00?011?0?1??111'],
#  ['1001110000111110011010100', '0??10?10??00?011?0?1??111'],
#  ['1001110100011010111010100', '0??10?1????0??1100?1??111'],
#  ['1101010100011010111010100', '00?1??1????0??1100?1??111'],
#  ['0001010000111010011010100', '???1??10??00??11?0?1??111'],
#  ['0001010000111110111010100', '???1??10??00?01100?1??111'],
#  ['0001010100011110111010100', '???1??1????0?01100?1??111'],
#  ['0001110000001010111010100', '???10?10??????1100?1??111'],
#  ['0101010100111010011010100', '?0?1??1???00??11?0?1??111'],
#  ['1001110000011010111010100', '0??10?10???0??1100?1??111']]

# %%
#(S_var[i].append(stats_L1[S_var[i][0]]) for i in range(len(S_var))
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
S_var
# Out:
# [['0001110100011010111010100', '???10?1????0??1100?1??111', 56],
#  ['0101010100011010111010100', '?0?1??1????0??1100?1??111', 56],
#  ['0001110000011010111010100', '???10?10???0??1100?1??111', 59],
#  ['0001110000011010011010100', '???10?10???0??11?0?1??111', 60],
#  ['0101010000011010111010100', '?0?1??10???0??1100?1??111', 61],
#  ['0001010000011010111010100', '???1??10???0??1100?1??111', 62],
#  ['0001010100011010111010100', '???1??1????0??1100?1??111', 63],
#  ['0101110100011010111010100', '?0?10?1????0??1100?1??111', 63],
#  ['0001110100011110011010100', '???10?1????0?011?0?1??111', 64],
#  ['0101110000011010111010100', '?0?10?10???0??1100?1??111', 64],
#  ['0001110100011010101010100', '???10?1????0??110??1??111', 65],
#  ['1001110000011010011010100', '0??10?10???0??11?0?1??111', 65],
#  ['1001110100011110011010100', '0??10?1????0?011?0?1??111', 65],
#  ['0001110000011010101010100', '???10?10???0??110??1??111', 66],
#  ['0001110000011010111000100', '???10?10???0??1100?10?111', 66],
#  ['0001110000111110011010100', '???10?10??00?011?0?1??111', 66],
#  ['0001110100111110111010100', '???10?1???00?01100?1??111', 66],
#  ['0101010100111110111010100', '?0?1??1???00?01100?1??111', 66],
#  ['0001010000011010111000100', '???1??10???0??1100?10?111', 67],
#  ['0001110100011010011010100', '???10?1????0??11?0?1??111', 67],
#  ['0101010000111110111010100', '?0?1??10??00?01100?1??111', 67],
#  ['0101010100011010011010100', '?0?1??1????0??11?0?1??111', 67],
#  ['0101010100011010101010100', '?0?1??1????0??110??1??111', 67],
#  ['0101010100111010111010100', '?0?1??1???00??1100?1??111', 67],
#  ['0001010100011010011010100', '???1??1????0??11?0?1??111', 68],
#  ['0001010100011010101010100', '???1??1????0??110??1??111', 68],
#  ['0001010100111110011010100', '???1??1???00?011?0?1??111', 68],
#  ['0001110000011110111010100', '???10?10???0?01100?1??111', 68],
#  ['0001110000111010111010100', '???10?10??00??1100?1??111', 68],
#  ['0001110100001010101010100', '???10?1???????110??1??111', 68],
#  ['0001110100111010011010100', '???10?1???00??11?0?1??111', 68],
#  ['0001110101010010111010100', '???10?1??0?00?1100?1??111', 68],
#  ['0101010000011110111010100', '?0?1??10???0?01100?1??111', 68],
#  ['0101010000111010111010100', '?0?1??10??00??1100?1??111', 68],
#  ['0101010101010010111010100', '?0?1??1??0?00?1100?1??111', 68],
#  ['0001010000011010101010100', '???1??10???0??110??1??111', 69],
#  ['0001110000011110011010100', '???10?10???0?011?0?1??111', 69],
#  ['0001110000111110111010100', '???10?10??00?01100?1??111', 69],
#  ['0001110001010010111010100', '???10?10?0?00?1100?1??111', 69],
#  ['0001110010011010111000100', '???10?100??0??1100?10?111', 69],
#  ['0001110100011110111010100', '???10?1????0?01100?1??111', 69],
#  ['0001110100111010111010100', '???10?1???00??1100?1??111', 69],
#  ['0101010100001010111010100', '?0?1??1???????1100?1??111', 69],
#  ['0101010100111110011010100', '?0?1??1???00?011?0?1??111', 69],
#  ['1001110000111110011010100', '0??10?10??00?011?0?1??111', 69],
#  ['1001110100011010111010100', '0??10?1????0??1100?1??111', 69],
#  ['1101010100011010111010100', '00?1??1????0??1100?1??111', 69],
#  ['0001010000111010011010100', '???1??10??00??11?0?1??111', 70],
#  ['0001010000111110111010100', '???1??10??00?01100?1??111', 70],
#  ['0001010100011110111010100', '???1??1????0?01100?1??111', 70],
#  ['0001110000001010111010100', '???10?10??????1100?1??111', 70],
#  ['0101010100111010011010100', '?0?1??1???00??11?0?1??111', 70],
#  ['1001110000011010111010100', '0??10?10???0??1100?1??111', 70]]

# %% [markdown]
# Generating all possible s-sequences using masks with '?' and given 'x' and 'y'. Each sequence is then used in Geffe generator and comared to zi.

# %%
for sublist in S_var:
    x, s, stats = sublist
    print(s)
    starting_s = copy(s)
    num_q = s.count('?')
    for i in range(2**num_q):
        if(i%1000 == 0):
            print(i)
        i = '{:0{}b}'.format(i, num_q)
        s = copy(starting_s)
        for l in i:
            s = s.replace('?', l, 1)
        s_repl = copy(s)
        for end in ['00', '01', '10', '11']:
            s = s_repl+end
            if (Geffe(len(zi), x, y, s) == zi):
                print(x, y, s)
# Out:
# ???10?1????0??1100?1??111
# 0
# 1000
# 2000
# 3000
# 0001110100011010111010100 00000111000010010011100111 010101111010111100010011110
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-58-503776803fa8> in <module>()
#      14         for end in ['00', '01', '10', '11']:
#      15             s = s_repl+end
# ---> 16             if (Geffe(len(zi), x, y, s) == zi):
#      17                 print(x, y, s)
#
# <ipython-input-11-51fc90f3f037> in Geffe(bit_len, L1_starting, L2_starting, L3_starting)
#       3        First generates L1, L2 and L3 sequences of len == bit_len using given starting bits
#       4        Then uses function z = sx ^ (1^ s)*y to generate output'''
# ----> 5     x = L1(L1_starting, bit_len)
#       6     y = L2(L2_starting, bit_len)
#       7     s = L3(L3_starting, bit_len)
#
# <ipython-input-8-f1ee7b8dedb5> in L1(starting_bits, bit_len)
#       7     #print(starting_bits)
#       8     for i in range(0, bit_len-25):
# ----> 9         x += str(int(x[i]) ^ int(x[i+3]))
#      10     return x
#
# KeyboardInterrupt:

# %% [markdown]
# FINAL KEYS

# %%
x_fin = '0001110100011010111010100'
y_fin = '00000111000010010011100111'
s_fin = '010101111010111100010011110'

# %% [markdown]
# FINAL SEQUENCE GENERATED WITH FINAL KEYS

# %%
z_fin = Geffe(len(zi), x_fin, y_fin, s_fin)
z_fin
# Out:
# '...'

# %%
z_fin == zi
# Out:
# True
